# %% [markdown]
# <a href="https://colab.research.google.com/github/Duchalsoham12/flyrank-ml-internship/blob/main/work/capstone.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # FlyRank Search Intelligence Capstone
#
# ## Lane
# Refresh / Content Opportunity Scoring
#
# ## Research Question
# Can safe search-performance signals be used to rank pages that deserve review for decline, recovery, or improvement?
#
# ## Goal
# Build and validate a repeatable model that produces a ranked list of pages for content review, with reason codes explaining why each page was recommended.

# %% [markdown]
# # ML-10 — Content Action Playbook
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Duchalsoham12/flyrank-ml-internship/blob/main/work/notebooks/w07_action_playbook.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Ranked actions + reason codes
#
# *The queue: what to do first, and why, in words a human trusts.*

# %%
import os
import pandas as pd
import numpy as np

from sklearn.model_selection import GroupShuffleSplit
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.ensemble import RandomForestClassifier

# --------------------------------------------------
# 1. Find and load dataset
# --------------------------------------------------

repo_path = "flyrank-ml-internship"

if not os.path.exists(repo_path):
    # !git clone https://github.com/Duchalsoham12/flyrank-ml-internship.git

csv_path = None

for root, dirs, files in os.walk(repo_path):
    for file in files:
        if file == "content_refresh_anonymized.csv":
            csv_path = os.path.join(root, file)

if csv_path is None:
    raise FileNotFoundError(
        "content_refresh_anonymized.csv not found."
    )

df = pd.read_csv(csv_path)

# Target
df["is_declining_label"] = (
    df["trend_direction"].astype(str).str.lower() == "down"
).astype(int)

print("Dataset:", df.shape)

# --------------------------------------------------
# 2. Client-grouped split
# --------------------------------------------------

gss = GroupShuffleSplit(
    n_splits=1,
    test_size=0.20,
    random_state=42
)

train_idx, test_idx = next(
    gss.split(
        df,
        y=df["is_declining_label"],
        groups=df["client_id"]
    )
)

train = df.iloc[train_idx].copy()
test = df.iloc[test_idx].copy()

print("Train:", train.shape)
print("Test:", test.shape)

# --------------------------------------------------
# 3. Prepare features
# --------------------------------------------------

excluded = {
    "content_id",
    "client_id",
    "trend_direction",
    "trend_pct",
    "is_declining_label"
}

features = [
    c for c in df.columns
    if c not in excluded
]

X_train = train[features]
y_train = train["is_declining_label"]

X_test = test[features]
y_test = test["is_declining_label"]

numeric_features = X_train.select_dtypes(
    include=np.number
).columns.tolist()

categorical_features = X_train.select_dtypes(
    exclude=np.number
).columns.tolist()

preprocessor = ColumnTransformer([
    (
        "num",
        SimpleImputer(strategy="median"),
        numeric_features
    ),
    (
        "cat",
        Pipeline([
            ("imputer", SimpleImputer(strategy="most_frequent")),
            ("onehot", OneHotEncoder(handle_unknown="ignore"))
        ]),
        categorical_features
    )
])

# --------------------------------------------------
# 4. Train Random Forest
# --------------------------------------------------

model = Pipeline([
    ("prep", preprocessor),
    ("rf", RandomForestClassifier(
        n_estimators=300,
        random_state=42,
        n_jobs=-1,
        class_weight="balanced"
    ))
])

model.fit(X_train, y_train)

# --------------------------------------------------
# 5. Predictions
# --------------------------------------------------

pred_prob = model.predict_proba(X_test)[:, 1]

# Precision@50
top_n = min(50, len(y_test))
top_indices = np.argsort(pred_prob)[::-1][:top_n]

honest_p50 = y_test.iloc[top_indices].mean()

print("Model trained successfully.")
print("Precision@50:", round(honest_p50, 3))
print(
    "Client overlap:",
    len(set(train["client_id"]) & set(test["client_id"]))
)
# Out:
# Cloning into 'flyrank-ml-internship'...
# remote: Enumerating objects: 302, done.
# remote: Counting objects: 100% (302/302), done.
# remote: Compressing objects: 100% (258/258), done.
# remote: Total 302 (delta 166), reused 92 (delta 28), pack-reused 0 (from 0)
# Receiving objects: 100% (302/302), 2.01 MiB | 6.23 MiB/s, done.
# Resolving deltas: 100% (166/166), done.
# Dataset: (30000, 45)
# Train: (23837, 45)
# Test: (6163, 45)
# Model trained successfully.
# Precision@50: 1.0
# Client overlap: 0

# %%
queue = test[
    [
        "content_id",
        "content_age_days",
        "days_since_last_update",
        "engagement_rate",
        "ai_traffic_pct",
        "trend_direction",
        "trend_pct"
    ]
].copy()

queue["decline_score"] = pred_prob

print("Queue created:", len(queue))
# Out:
# Queue created: 6163

# %%
def reason_code(row):
    reasons = []

    if row["days_since_last_update"] > 180:
        reasons.append("STALE_CONTENT")

    if (
        pd.notna(row["engagement_rate"])
        and row["engagement_rate"] < 0.50
    ):
        reasons.append("LOW_ENGAGEMENT")

    if (
        pd.notna(row["trend_pct"])
        and row["trend_pct"] < 0
    ):
        reasons.append("NEGATIVE_TREND")

    if not reasons:
        reasons.append("MODEL_PRIORITY")

    return "|".join(reasons)


queue["reason_code"] = queue.apply(
    reason_code,
    axis=1
)

print("Reason codes created.")
# Out:
# Reason codes created.

# %%
def get_recommended_action(row):
    reason = str(row["reason_code"])

    if (
        "STALE_CONTENT" in reason
        and "NEGATIVE_TREND" in reason
    ):
        return "REFRESH_CONTENT"

    elif (
        "LOW_ENGAGEMENT" in reason
        and "NEGATIVE_TREND" in reason
    ):
        return "REVIEW_INTENT_AND_REFRESH"

    elif "LOW_ENGAGEMENT" in reason:
        return "REVIEW_CONTENT_QUALITY"

    elif "NEGATIVE_TREND" in reason:
        return "INVESTIGATE_DECLINE"

    else:
        return "HUMAN_REVIEW"


queue["recommended_action"] = queue.apply(
    get_recommended_action,
    axis=1
)

print("Recommended actions created.")
# Out:
# Recommended actions created.

# %%
queue = queue.sort_values(
    "decline_score",
    ascending=False
).reset_index(drop=True)

queue["priority_rank"] = np.arange(
    1,
    len(queue) + 1
)

print("Priority ranking created.")
# Out:
# Priority ranking created.

# %%
display(
    queue[
        [
            "priority_rank",
            "content_id",
            "decline_score",
            "reason_code",
            "recommended_action"
        ]
    ].head(20)
)
# Out:
#     priority_rank            content_id  decline_score  \
# 0               1  content_29884c0f9255       0.976667
# 1               2  content_eb3b2c3bbc34       0.970000
# 2               3  content_41538bdb1b1e       0.966667
# 3               4  content_9234f5075e7a       0.963333
# 4               5  content_9ac61c04930e       0.963333
# 5               6  content_f6bf66378677       0.963333
# 6               7  content_9e8671965fff       0.956667
# 7               8  content_c6bb205d5263       0.956667
# 8               9  content_8b08ec7fc725       0.953333
# 9              10  content_e5fd30b6e33b       0.950000
# 10             11  content_102d1a1e54a6       0.950000
# 11             12  content_769c5991e2f6       0.950000
# 12             13  content_f55fd2d8ed04       0.950000
# 13             14  content_edf5b03b36aa       0.946667
# 14             15  content_e988c1699454       0.946667
# 15             16  content_0b50482209cd       0.946667
# 16             17  content_1bdbccd74939       0.946667
# 17             18  content_3395aba722a2       0.943333
# 18             19  content_207fe9e3ad65       0.943333
# 19             20  content_cb372c0a7708       0.943333
#
#                       reason_code         recommended_action
# 0   LOW_ENGAGEMENT|NEGATIVE_TREND  REVIEW_INTENT_AND_REFRESH
# 1   LOW_ENGAGEMENT|NEGATIVE_TREND  REVIEW_INTENT_AND_REFRESH
# 2   LOW_ENGAGEMENT|NEGATIVE_TREND  REVIEW_INTENT_AND_REFRESH
# 3   LOW_ENGAGEMENT|NEGATIVE_TREND  REVIEW_INTENT_AND_REFRESH
# 4   LOW_ENGAGEMENT|NEGATIVE_TREND  REVIEW_INTENT_AND_REFRESH
# 5   LOW_ENGAGEMENT|NEGATIVE_TREND  REVIEW_INTENT_AND_REFRESH
# 6   LOW_ENGAGEMENT|NEGATIVE_TREND  REVIEW_INTENT_AND_REFRESH
# 7   LOW_ENGAGEMENT|NEGATIVE_TREND  REVIEW_INTENT_AND_REFRESH
# 8   LOW_ENGAGEMENT|NEGATIVE_TREND  REVIEW_INTENT_AND_REFRESH
# 9   LOW_ENGAGEMENT|NEGATIVE_TREND  REVIEW_INTENT_AND_REFRESH
# 10  LOW_ENGAGEMENT|NEGATIVE_TREND  REVIEW_INTENT_AND_REFRESH
# 11  LOW_ENGAGEMENT|NEGATIVE_TREND  REVIEW_INTENT_AND_REFRESH
# 12  LOW_ENGAGEMENT|NEGATIVE_TREND  REVIEW_INTENT_AND_REFRESH
# 13  LOW_ENGAGEMENT|NEGATIVE_TREND  REVIEW_INTENT_AND_REFRESH
# 14  LOW_ENGAGEMENT|NEGATIVE_TREND  REVIEW_INTENT_AND_REFRESH
# 15  LOW_ENGAGEMENT|NEGATIVE_TREND  REVIEW_INTENT_AND_REFRESH
# 16  LOW_ENGAGEMENT|NEGATIVE_TREND  REVIEW_INTENT_AND_REFRESH
# 17                 NEGATIVE_TREND        INVESTIGATE_DECLINE
# 18  LOW_ENGAGEMENT|NEGATIVE_TREND  REVIEW_INTENT_AND_REFRESH
# 19  LOW_ENGAGEMENT|NEGATIVE_TREND  REVIEW_INTENT_AND_REFRESH

# %%
print("Queue size:", len(queue))

print(
    "Highest decline score:",
    round(queue["decline_score"].max(), 3)
)

print(
    "Lowest decline score:",
    round(queue["decline_score"].min(), 3)
)

print("\nReason-code counts:")

display(
    queue["reason_code"]
    .value_counts()
    .head(10)
    .to_frame("count")
)
# Out:
# Queue size: 6163
# Highest decline score: 0.977
# Lowest decline score: 0.003
#
# Reason-code counts:
#                                count
# reason_code
# LOW_ENGAGEMENT|NEGATIVE_TREND   2995
# LOW_ENGAGEMENT                  1829
# NEGATIVE_TREND                   874
# MODEL_PRIORITY                   465

# %%
review_queue = queue.head(20).copy()

print(
    "Items requiring human review:",
    len(review_queue)
)

display(
    review_queue[
        [
            "priority_rank",
            "content_id",
            "decline_score",
            "reason_code",
            "recommended_action"
        ]
    ]
)
# Out:
# Items requiring human review: 20
#     priority_rank            content_id  decline_score  \
# 0               1  content_29884c0f9255       0.976667
# 1               2  content_eb3b2c3bbc34       0.970000
# 2               3  content_41538bdb1b1e       0.966667
# 3               4  content_9234f5075e7a       0.963333
# 4               5  content_9ac61c04930e       0.963333
# 5               6  content_f6bf66378677       0.963333
# 6               7  content_9e8671965fff       0.956667
# 7               8  content_c6bb205d5263       0.956667
# 8               9  content_8b08ec7fc725       0.953333
# 9              10  content_e5fd30b6e33b       0.950000
# 10             11  content_102d1a1e54a6       0.950000
# 11             12  content_769c5991e2f6       0.950000
# 12             13  content_f55fd2d8ed04       0.950000
# 13             14  content_edf5b03b36aa       0.946667
# 14             15  content_e988c1699454       0.946667
# 15             16  content_0b50482209cd       0.946667
# 16             17  content_1bdbccd74939       0.946667
# 17             18  content_3395aba722a2       0.943333
# 18             19  content_207fe9e3ad65       0.943333
# 19             20  content_cb372c0a7708       0.943333
#
#                       reason_code         recommended_action
# 0   LOW_ENGAGEMENT|NEGATIVE_TREND  REVIEW_INTENT_AND_REFRESH
# 1   LOW_ENGAGEMENT|NEGATIVE_TREND  REVIEW_INTENT_AND_REFRESH
# 2   LOW_ENGAGEMENT|NEGATIVE_TREND  REVIEW_INTENT_AND_REFRESH
# 3   LOW_ENGAGEMENT|NEGATIVE_TREND  REVIEW_INTENT_AND_REFRESH
# 4   LOW_ENGAGEMENT|NEGATIVE_TREND  REVIEW_INTENT_AND_REFRESH
# 5   LOW_ENGAGEMENT|NEGATIVE_TREND  REVIEW_INTENT_AND_REFRESH
# 6   LOW_ENGAGEMENT|NEGATIVE_TREND  REVIEW_INTENT_AND_REFRESH
# 7   LOW_ENGAGEMENT|NEGATIVE_TREND  REVIEW_INTENT_AND_REFRESH
# 8   LOW_ENGAGEMENT|NEGATIVE_TREND  REVIEW_INTENT_AND_REFRESH
# 9   LOW_ENGAGEMENT|NEGATIVE_TREND  REVIEW_INTENT_AND_REFRESH
# 10  LOW_ENGAGEMENT|NEGATIVE_TREND  REVIEW_INTENT_AND_REFRESH
# 11  LOW_ENGAGEMENT|NEGATIVE_TREND  REVIEW_INTENT_AND_REFRESH
# 12  LOW_ENGAGEMENT|NEGATIVE_TREND  REVIEW_INTENT_AND_REFRESH
# 13  LOW_ENGAGEMENT|NEGATIVE_TREND  REVIEW_INTENT_AND_REFRESH
# 14  LOW_ENGAGEMENT|NEGATIVE_TREND  REVIEW_INTENT_AND_REFRESH
# 15  LOW_ENGAGEMENT|NEGATIVE_TREND  REVIEW_INTENT_AND_REFRESH
# 16  LOW_ENGAGEMENT|NEGATIVE_TREND  REVIEW_INTENT_AND_REFRESH
# 17                 NEGATIVE_TREND        INVESTIGATE_DECLINE
# 18  LOW_ENGAGEMENT|NEGATIVE_TREND  REVIEW_INTENT_AND_REFRESH
# 19  LOW_ENGAGEMENT|NEGATIVE_TREND  REVIEW_INTENT_AND_REFRESH

# %%
monitoring_df = pd.DataFrame({
    "metric": [
        "Test rows",
        "Decline rate",
        "Precision@50",
        "Test clients"
    ],
    "value": [
        len(test),
        round(y_test.mean(), 3),
        round(honest_p50, 3),
        test["client_id"].nunique()
    ]
})

display(monitoring_df)
# Out:
#          metric     value
# 0     Test rows  6163.000
# 1  Decline rate     0.511
# 2  Precision@50     1.000
# 3  Test clients     7.000

# %%
monitoring_rules = pd.DataFrame({
    "trigger": [
        "Precision@50 decreases materially",
        "Decline rate changes substantially",
        "Important feature distributions shift",
        "Important fields become missing",
        "Data definitions or collection process change",
        "New labeled data becomes available"
    ],
    "response": [
        "Review model ranking quality",
        "Investigate whether the content environment changed",
        "Check for data drift and reassess model validity",
        "Investigate the data pipeline before using recommendations",
        "Revalidate the model and feature definitions",
        "Consider retraining and revalidation"
    ]
})

display(monitoring_rules)
# Out:
#                                          trigger  \
# 0              Precision@50 decreases materially
# 1             Decline rate changes substantially
# 2          Important feature distributions shift
# 3                Important fields become missing
# 4  Data definitions or collection process change
# 5             New labeled data becomes available
#
#                                             response
# 0                       Review model ranking quality
# 1  Investigate whether the content environment ch...
# 2   Check for data drift and reassess model validity
# 3  Investigate the data pipeline before using rec...
# 4       Revalidate the model and feature definitions
# 5               Consider retraining and revalidation

# %%
decay_summary = pd.DataFrame({
    "metric": [
        "Median content age (days)",
        "Median days since last update",
        "Median trend (%)",
        "Median decline score"
    ],
    "value": [
        round(queue["content_age_days"].median(), 1),
        round(queue["days_since_last_update"].median(), 1),
        round(queue["trend_pct"].median(), 1),
        round(queue["decline_score"].median(), 3)
    ]
})

display(decay_summary)
# Out:
#                           metric    value
# 0      Median content age (days)  277.000
# 1  Median days since last update   20.000
# 2               Median trend (%)  -29.700
# 3           Median decline score    0.547

# %% [markdown]
# The ranked queue is intended to help a content team spend limited review time on the highest-priority items first.
#
# A high model score does not automatically mean that an expensive content change is worthwhile. Reviewers should consider expected value, business importance, effort required, and the risk of making the change.
#
# Low-cost actions such as checking freshness, search intent, or obvious content gaps can be considered before higher-cost actions such as a major rewrite.
#
# The model therefore supports prioritization of review effort; it does not calculate guaranteed business value or recommend an action without human judgment.

# %%
import os

output_dir = "flyrank-ml-internship/work/outputs"

os.makedirs(
    output_dir,
    exist_ok=True
)

# Ranked action queue
queue_path = os.path.join(
    output_dir,
    "ml10_ranked_action_queue.csv"
)

queue.to_csv(
    queue_path,
    index=False
)

# Monitoring summary
monitoring_path = os.path.join(
    output_dir,
    "ml10_monitoring_summary.csv"
)

monitoring_df.to_csv(
    monitoring_path,
    index=False
)

print("Files exported successfully:")
print("-", queue_path)
print("-", monitoring_path)
# Out:
# Files exported successfully:
# - flyrank-ml-internship/work/outputs/ml10_ranked_action_queue.csv
# - flyrank-ml-internship/work/outputs/ml10_monitoring_summary.csv

# %%
exported_queue = pd.read_csv(queue_path)

required_columns = [
    "content_id",
    "decline_score",
    "reason_code",
    "recommended_action",
    "priority_rank"
]

print(
    "Exported queue shape:",
    exported_queue.shape
)

print("\nRequired columns:")

for col in required_columns:
    print(
        col,
        "->",
        col in exported_queue.columns
    )

print("\nTop 10 ranked actions:")

display(
    exported_queue[
        required_columns
    ].head(10)
)
# Out:
# Exported queue shape: (6163, 11)
#
# Required columns:
# content_id -> True
# decline_score -> True
# reason_code -> True
# recommended_action -> True
# priority_rank -> True
#
# Top 10 ranked actions:
#              content_id  decline_score                    reason_code  \
# 0  content_29884c0f9255       0.976667  LOW_ENGAGEMENT|NEGATIVE_TREND
# 1  content_eb3b2c3bbc34       0.970000  LOW_ENGAGEMENT|NEGATIVE_TREND
# 2  content_41538bdb1b1e       0.966667  LOW_ENGAGEMENT|NEGATIVE_TREND
# 3  content_9234f5075e7a       0.963333  LOW_ENGAGEMENT|NEGATIVE_TREND
# 4  content_9ac61c04930e       0.963333  LOW_ENGAGEMENT|NEGATIVE_TREND
# 5  content_f6bf66378677       0.963333  LOW_ENGAGEMENT|NEGATIVE_TREND
# 6  content_9e8671965fff       0.956667  LOW_ENGAGEMENT|NEGATIVE_TREND
# 7  content_c6bb205d5263       0.956667  LOW_ENGAGEMENT|NEGATIVE_TREND
# 8  content_8b08ec7fc725       0.953333  LOW_ENGAGEMENT|NEGATIVE_TREND
# 9  content_e5fd30b6e33b       0.950000  LOW_ENGAGEMENT|NEGATIVE_TREND
#
#           recommended_action  priority_rank
# 0  REVIEW_INTENT_AND_REFRESH              1
# 1  REVIEW_INTENT_AND_REFRESH              2
# 2  REVIEW_INTENT_AND_REFRESH              3
# 3  REVIEW_INTENT_AND_REFRESH              4
# 4  REVIEW_INTENT_AND_REFRESH              5
# 5  REVIEW_INTENT_AND_REFRESH              6
# 6  REVIEW_INTENT_AND_REFRESH              7
# 7  REVIEW_INTENT_AND_REFRESH              8
# 8  REVIEW_INTENT_AND_REFRESH              9
# 9  REVIEW_INTENT_AND_REFRESH             10

# %%
print(
    os.path.exists(
        "flyrank-ml-internship/work/outputs/ml10_ranked_action_queue.csv"
    )
)

print(
    os.path.exists(
        "flyrank-ml-internship/work/outputs/ml10_monitoring_summary.csv"
    )
)
# Out:
# True
# True

# %%
# %cd /content/flyrank-ml-internship
# !git status
# Out:
# /content/flyrank-ml-internship
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# %cd /content/flyrank-ml-internship

# !git status
# Out:
# /content/flyrank-ml-internship
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git add work/notebooks/capstone.ipynb

# %%
# !git commit -m "Complete capstone notebook"
# Out:
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@3a7ba9a51d1d.(none)')

# %%
# !git config --global user.name "Soham Duchal"
# !git config --global user.email "YOUR_GITHUB_EMAIL"

# %%
# !git config --global user.name "Soham Duchal"
# !git config --global user.email "soham@gmail.com"

# %%
# !git commit -m "Complete capstone notebook"
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git push origin main
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !git remote -v
# Out:
# origin	https://github.com/Duchalsoham12/flyrank-ml-internship.git (fetch)
# origin	https://github.com/Duchalsoham12/flyrank-ml-internship.git (push)

# %%
from getpass import getpass

token = getpass("Enter your GitHub Personal Access Token: ")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_557/3086984320.py in <cell line: 0>()
#       1 from getpass import getpass
#       2
# ----> 3 token = getpass("Enter your GitHub Personal Access Token: ")
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in getpass(self, prompt, stream)
#    1157                 stacklevel=2,
#    1158             )
# -> 1159         return self._input_request(
#    1160             prompt,
#    1161             self._parent_ident["shell"],
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
from google.colab import userdata

token = userdata.get("GITHUB_TOKEN")

# !git remote set-url origin https://Duchalsoham12:{token}@github.com/Duchalsoham12/flyrank-ml-internship.git

# %%
# !git push origin main
# Out:
# Everything up-to-date

# %%
from google.colab import userdata

token = userdata.get("GITHUB_TOKEN")

if not token:
    raise ValueError("GITHUB_TOKEN secret not found")

print("GitHub token loaded successfully")
# Out:
# GitHub token loaded successfully

# %%
# !git remote set-url origin https://Duchalsoham12:{token}@github.com/Duchalsoham12/flyrank-ml-internship.git

# %%
# !git commit -m "Complete capstone notebook"
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# %cd /content/flyrank-ml-internship
# Out:
# /content/flyrank-ml-internship

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git push origin main
# Out:
# Everything up-to-date

# %%
from google.colab import userdata

token = userdata.get("GITHUB_TOKEN")

if not token:
    raise ValueError("GITHUB_TOKEN not found")

print("Token loaded successfully")
# Out:
# Token loaded successfully

# %%
# !git remote set-url origin https://Duchalsoham12:{token}@github.com/Duchalsoham12/flyrank-ml-internship.git

# %%
# !git push origin main
# Out:
# Everything up-to-date

# %%
# %cd /content/flyrank-ml-internship
# !git pull --rebase origin main
# Out:
# /content/flyrank-ml-internship
# From https://github.com/Duchalsoham12/flyrank-ml-internship
#  * branch            main       -> FETCH_HEAD
# Already up to date.

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git push origin main
# Out:
# Everything up-to-date

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# %cd /content/flyrank-ml-internship
# !git status
# Out:
# /content/flyrank-ml-internship
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %% [markdown]
# ## 10. 5-Minute Demo Outline
#
# ### 1. Question — 45 seconds
#
# Can safe search-performance signals be used to rank content pages that deserve review for decline, recovery, or improvement?
#
# ### 2. Method — 1 minute
#
# I used 30,000 anonymized content records across 32 clients. I excluded client identifiers and label-derived fields from the model features to reduce leakage. I trained a Random Forest classifier and evaluated it using an 80/20 client-grouped split, with 25 clients for training and 7 clients for testing.
#
# ### 3. One Chart — 1 minute
#
# Show the comparison of **Precision@50** between the transparent baseline and the Random Forest model:
#
# - Baseline: **1.000**
# - Random Forest: **1.000**
# - Improvement: **0.000**
#
# Precision@50 measures the proportion of the top 50 ranked records that belong to the observed decline class.
#
# ### 4. One Honest Result — 1 minute
#
# The Random Forest achieved **Precision@50 of 1.000** on the held-out test set, exactly matching the trend-based baseline at **1.000**.
#
# Therefore, this experiment does **not** show that the Random Forest outperforms the baseline. Instead, both approaches achieved the same top-50 ranking performance on this particular client-grouped test split.
#
# ### 5. One Recommendation — 1 minute
#
# Use the ranked output as a human-review queue. Content teams can start with the highest-ranked pages, inspect the supporting signals such as negative trend and low engagement, and then decide whether a refresh, investigation, or quality review is appropriate.
#
# ### Closing — 15 seconds
#
# The model is a decision-support system for prioritizing editorial review, not an automatic content decision-maker. The results are specific to this validation split and should be revalidated on new data before production use.

# %% [markdown]
# ## 11. Shareable Project Summary
#
# ### Social Post
#
# I built a machine-learning workflow to help prioritize content pages that may be declining in search performance. Using 30,000 content records across 32 clients, I trained and evaluated a Random Forest model with non-leaking search-performance signals and a client-grouped evaluation split. The model achieved **Precision@50 of 1.00**, matching the transparent baseline at **1.00** on the held-out test set. The result is designed as a decision-support workflow that helps content teams decide which pages deserve review first.
#
# ### Employer-Facing Summary
#
# I built a machine-learning content decline detection workflow using 30,000 FlyRank content-performance records across 32 clients. I trained a Random Forest model using non-leaking search-performance signals and evaluated it with a client-grouped 80/20 split. The model achieved **Precision@50 of 1.00**, matching the baseline at **1.00**, and produced a ranked queue for editorial review and prioritization.

# %% [markdown]
# ### Monitoring and Retrain Rules
#
# The model should be monitored as a decision-support tool rather than treated as a fixed production system.
#
# **Review trigger:** Review the playbook if Precision@50 decreases materially on newly labeled data, the decline rate changes substantially, or the distribution of important input features shifts.
#
# **Retrain trigger:** Consider retraining when enough new labeled observations are available and the current model no longer gives useful ranking performance.
#
# **Data trigger:** Recheck the pipeline if important fields become missing, definitions change, or the data collection process changes.
#
# These are review triggers, not automatic production thresholds. A human should decide whether retraining or redesign is necessary.

# %%
# %cd /content/flyrank-ml-internship
# !git status
# Out:
# /content/flyrank-ml-internship
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
